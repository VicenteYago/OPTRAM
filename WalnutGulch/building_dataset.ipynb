# %% [markdown]
# # Dataset_v0

# %% [markdown]
# Building first version of the dataset for deep learning

# %% [markdown]
# - Satellite:
#  - NIR
#  - R
#  - G
#  - B
#  - NDVI
#  - SWIR
#  - W
#  - THETA (target)
# - Dataframe
#  - inSitu obs (ground truth obs)

# %% [markdown]
# ## 1 - Python packages

# %%
# MODULE                                             # DESCRIPTION
                                      # bidirectional UTM-WGS84 converter
import rasterio as rs                                # raster and geospatial data proc.
import matplotlib.pyplot as plt                      # create visualizations
import datetime                                      # datetime manipulation
import glob                                          # unix pathname expansion
import colorcet as cc                                # colormaps for datashader 
import xarray as xr                                  # efficent ND arrays manipulation
import rioxarray                                     # rasterio xarray extension
import pickle                                        # load/save pickle datasets
import os                                            # miscellaneous OS interfaces
from pathlib import Path                             #                                      #
import shutil
import re
import glob

def  get_date_str_S2_file(filename):
    m = re.match('S2(A|B)2A_([0-9]+)_',filename)
    date = m.group(2)
    return (date)

# %% [markdown]
# ## 2 Satellite Data

# %% [markdown]
# ### 2.1 - Copying raw files

# %%
BASE_DIR       = "./dataset_v0/"

BASE_DIR_BOA   = "./sen2r/out/BOA2"
BASE_DIR_SCL   = "./dataset_v0/SCL"
BASE_DIR_R     = "./dataset_v0/R"
BASE_DIR_G     = "./dataset_v0/G"
BASE_DIR_B     = "./dataset_v0/B"
BASE_DIR_NIR   = "./dataset_v0/NIR"


BASE_DIR_NDVI_old = "./sen2r/indices/NDVI"
BASE_DIR_NDVI  = "./dataset_v0/NDVI"

BASE_DIR_SWIR  = "./dataset_v0/SWIR"

BASE_DIR_W     = "./dataset_v0/W"
BASE_DIR_THETA = "./dataset_v0/THETA"

Path(BASE_DIR).mkdir(parents=True, exist_ok=True)
Path(BASE_DIR_R).mkdir(parents=True, exist_ok=True)
Path(BASE_DIR_G).mkdir(parents=True, exist_ok=True)
Path(BASE_DIR_B).mkdir(parents=True, exist_ok=True)
Path(BASE_DIR_NIR).mkdir(parents=True, exist_ok=True)
Path(BASE_DIR_NDVI).mkdir(parents=True, exist_ok=True)
Path(BASE_DIR_SWIR).mkdir(parents=True, exist_ok=True)
Path(BASE_DIR_W).mkdir(parents=True, exist_ok=True)
Path(BASE_DIR_THETA).mkdir(parents=True, exist_ok=True)
Path(BASE_DIR_SCL).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# W,theta,ndvi bands are already computed as independent files. We only need to copy them to the new folder:

# %%
! cp -r ./W_maps/* ./dataset_v0/W

# %%
! cp -r ./theta_maps/* ./dataset_v0/THETA/

# %%
! cp -r ./sen2r/out/SCL_res10/* ./dataset_v0/SCL/

# %%
w_files = [f for f in os.listdir(BASE_DIR_W) if os.path.isfile(os.path.join(BASE_DIR_W, f))]

for idx,file in enumerate(w_files): 
    
    try : 
        
        now = datetime.datetime.now().strftime("%Y/%m/%d %H:%M:%S")
        print('[%s] : processing file (%s/%s) %s... \n' % (now, idx, len(w_files), file))
        
        w_fp = os.path.join(BASE_DIR_W, file)
        basename_fp = w_fp[len(BASE_DIR_W)+1:-5]
        
        
        # NDVI
        old_ndvi_fp = os.path.join(BASE_DIR_NDVI_old, basename_fp+"NDVI_10.tif")
        new_ndvi_fp = os.path.join(BASE_DIR_NDVI, basename_fp+"NDVI_10.tif")
        shutil.copyfile(old_ndvi_fp, new_ndvi_fp)
        
        # BOA - R,G,B,NIR
        boa_fp = os.path.join(BASE_DIR_BOA, basename_fp+"BOA_10.tif")
        boa    = rs.open(boa_fp)
        
        r    = boa.read(4)
        g    = boa.read(3)
        b    = boa.read(2)
        swir = boa.read(11)
        nir  = boa.read(8)
        
        out_meta = boa.meta.copy()
        out_meta["count"] = 1
        with rs.open(fp=os.path.join(BASE_DIR_R, basename_fp+"R_10.tif"), 
                     mode='w',**out_meta) as dst:
                     dst.write(r, 1)
                
        with rs.open(fp=os.path.join(BASE_DIR_G, basename_fp+"G_10.tif"), 
                     mode='w',**out_meta) as dst:
                     dst.write(g, 1) 

        with rs.open(fp=os.path.join(BASE_DIR_B, basename_fp+"B_10.tif"), 
                     mode='w',**out_meta) as dst:
                     dst.write(b, 1) 
                
        with rs.open(fp=os.path.join(BASE_DIR_NIR, basename_fp+"NIR_10.tif"), 
                     mode='w',**out_meta) as dst:
                     dst.write(nir, 1)

        with rs.open(fp=os.path.join(BASE_DIR_SWIR, basename_fp+"SWIR_10.tif"), 
                     mode='w',**out_meta) as dst:
                     dst.write(swir, 1)
                
        boa.close()
        
    except Exception as e : 
        print("An error occurred while processing data for sensor %s " % file)
        print("Original message: %s " % e)
# Out:
# [2022/05/06 12:16:29] : processing file (0/71) S2A2A_20191211_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:29] : processing file (1/71) S2A2A_20190614_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:30] : processing file (2/71) S2B2A_20190510_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:32] : processing file (3/71) S2A2A_20190823_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:33] : processing file (4/71) S2B2A_20190818_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:33] : processing file (5/71) S2A2A_20190704_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:35] : processing file (6/71) S2A2A_20191201_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:36] : processing file (7/71) S2B2A_20190907_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:37] : processing file (8/71) S2B2A_20191216_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:39] : processing file (9/71) S2B2A_20190110_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:40] : processing file (10/71) S2B2A_20190311_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:41] : processing file (11/71) S2A2A_20191101_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:41] : processing file (12/71) S2A2A_20190803_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:43] : processing file (13/71) S2A2A_20190525_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:43] : processing file (14/71) S2A2A_20190306_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:43] : processing file (15/71) S2B2A_20190709_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:43] : processing file (16/71) S2A2A_20190316_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:44] : processing file (17/71) S2B2A_20190420_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:44] : processing file (18/71) S2A2A_20190224_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:45] : processing file (19/71) S2B2A_20190619_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:45] : processing file (20/71) S2B2A_20190927_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:47] : processing file (21/71) S2B2A_20190609_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:48] : processing file (22/71) S2B2A_20191017_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:50] : processing file (23/71) S2A2A_20191022_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:51] : processing file (24/71) S2A2A_20190624_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:51] : processing file (25/71) S2B2A_20190629_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:53] : processing file (26/71) S2A2A_20190922_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:53] : processing file (27/71) S2A2A_20191002_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:55] : processing file (28/71) S2A2A_20190505_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:55] : processing file (29/71) S2B2A_20190430_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:57] : processing file (30/71) S2A2A_20190714_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:58] : processing file (31/71) S2A2A_20190214_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:16:58] : processing file (32/71) S2A2A_20191121_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:00] : processing file (33/71) S2A2A_20190425_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:00] : processing file (34/71) S2B2A_20190331_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:00] : processing file (35/71) S2B2A_20190530_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:02] : processing file (36/71) S2B2A_20190828_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:03] : processing file (37/71) S2B2A_20190808_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:03] : processing file (38/71) S2B2A_20190209_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:03] : processing file (39/71) S2B2A_20190917_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:03] : processing file (40/71) S2B2A_20191007_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:04] : processing file (41/71) S2A2A_20190912_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:04] : processing file (42/71) S2A2A_20190604_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:04] : processing file (43/71) S2A2A_20190326_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:04] : processing file (44/71) S2B2A_20191126_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:05] : processing file (45/71) S2A2A_20190405_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:05] : processing file (46/71) S2B2A_20190301_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:05] : processing file (47/71) S2A2A_20191221_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:05] : processing file (48/71) S2B2A_20191106_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:05] : processing file (49/71) S2A2A_20191231_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:06] : processing file (50/71) S2B2A_20191206_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:06] : processing file (51/71) S2A2A_20190204_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:06] : processing file (52/71) S2B2A_20191226_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:06] : processing file (53/71) S2B2A_20190130_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:06] : processing file (54/71) S2B2A_20190321_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:07] : processing file (55/71) S2B2A_20191027_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:07] : processing file (56/71) S2A2A_20190125_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:07] : processing file (57/71) S2B2A_20190719_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:07] : processing file (58/71) S2B2A_20190219_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:07] : processing file (59/71) S2A2A_20190105_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:08] : processing file (60/71) S2B2A_20191116_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:08] : processing file (61/71) S2A2A_20190813_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:08] : processing file (62/71) S2B2A_20190120_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:08] : processing file (63/71) S2A2A_20191111_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:08] : processing file (64/71) S2A2A_20190515_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:09] : processing file (65/71) S2B2A_20190410_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:09] : processing file (66/71) S2B2A_20190729_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:09] : processing file (67/71) S2A2A_20190415_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:09] : processing file (68/71) S2A2A_20191012_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:09] : processing file (69/71) S2A2A_20190724_041_Walnut-Gulch_W.tif...
#
# [2022/05/06 12:17:09] : processing file (70/71) S2A2A_20190902_041_Walnut-Gulch_W.tif...

# %% [markdown]
# ### 2.2 - Masking all bands based on SCL

# %% [markdown]
# Not al bands need to be masked, i.e. W and theta are already masked.

# %%
band_dirs = [BASE_DIR_B,
             BASE_DIR_G,
             BASE_DIR_R,
             BASE_DIR_NIR,
             BASE_DIR_NDVI,
             BASE_DIR_SWIR]

# %%
for band_dir in band_dirs : 
    print('processing band dir %s ... \n' % (band_dir))
    band_dir_masked = os.path.join(band_dir, "masked")
    Path(band_dir_masked).mkdir(parents=True, exist_ok=True)
    print(band_dir)
    band_files = [f for f in os.listdir(band_dir) if os.path.isfile(os.path.join(band_dir, f))]
    #print(band_files)
    
    for band_file in band_files : 
        try: 
            print('--- processing file %s ... \n' % (band_file))
            band_file_date = get_date_str_S2_file(band_file)
            scl_file = glob.glob(os.path.join(BASE_DIR_SCL,"*"+band_file_date+"*"))[0]
            print(scl_file)

            scl = rioxarray.open_rasterio(scl_file, masked=True)
            scl = scl[0]
            scl = scl.rename({'band':'scl'})

            band = rioxarray.open_rasterio(os.path.join(band_dir,band_file), masked=True)
            band = band[0]
            band = band.rename({'band':'band'})

            band_masked = band.where(
                                (scl == 4) | # vegetation
                                (scl == 5) | # not_vegetated
                                (scl == 6)   # water
                              )

            band_masked.rio.to_raster(os.path.join(band_dir_masked, band_file))
            
        except Exception as e :
            print("An error occurred while processing file %s " % band_file)
            print("Original message: %s " % e)
# Out:
# processing band dir ./dataset_v0/B ...
#
# ./dataset_v0/B
# --- processing file S2B2A_20190430_041_Walnut-Gulch_B_10.tif ...
#
# ./dataset_v0/SCL/20
                            (scl == 6)   # water
                          )
        
        band.rio.to_raster(os.path.join(dir, file))

# %% [markdown]
# ## 3 - Dataframe data

# %%
! cp ./inSitu_dfs_global.pkl ./dataset_v0/

# %%
! cp ./inSitu_dfs_global_masked.pkl ./dataset_v0/

# %% [markdown]
# ## 4 - Quality checks

# %%
dir_lens = map(lambda dir : len(os.listdir(dir)), band_dirs)
dir_lens = list(dir_lens)

# %%
dict(zip(band_dirs, dir_lens))
# Out:
# {'./dataset_v0/SCL': 71,
#  './dataset_v0/R': 72,
#  './dataset_v0/G': 72,
#  './dataset_v0/B': 72,
#  './dataset_v0/NIR': 72,
#  './dataset_v0/NDVI': 72,
#  './dataset_v0/SWIR': 72,
#  './dataset_v0/W': 72,
#  './dataset_v0/THETA': 72}

# %%
band_dirs.remove('./dataset_v0/SCL')
band_dirs
# Out:
# ['./dataset_v0/R',
#  './dataset_v0/G',
#  './dataset_v0/B',
#  './dataset_v0/NIR',
#  './dataset_v0/NDVI',
#  './dataset_v0/SWIR',
#  './dataset_v0/W',
#  './dataset_v0/THETA']

# %% [markdown]
# SCL has one item less, thats OK because ot the lack of mask folder

# %%
dates_df = pd.DataFrame()
for band_dir in band_dirs : 
    files = (file for file in os.listdir(band_dir) if os.path.isfile(os.path.join(band_dir, file)))
    files_list = list(files)
    dates_df[band_dir] = list(map(get_date_str_S2_file, files_list))

# %%
dates_df = dates_df.apply(lambda x: x.sort_values().values)
dates_df
# Out:
#    ./dataset_v0/R ./dataset_v0/G ./dataset_v0/B ./dataset_v0/NIR  \
# 0        20190105       20190105       20190105         20190105
# 1        20190110       20190110       20190110         20190110
# 2        20190120       20190120       20190120         20190120
# 3        20190125       20190125       20190125         20190125
# 4        20190130       20190130       20190130         20190130
# ..            ...            ...            ...              ...
# 66       20191211       20191211       20191211         20191211
# 67       20191216       20191216       20191216         20191216
# 68       20191221       20191221       20191221         20191221
# 69       20191226       20191226       20191226         20191226
# 70       20191231       20191231       20191231         20191231
#
#    ./dataset_v0/NDVI ./dataset_v0/SWIR ./dataset_v0/W ./dataset_v0/THETA
# 0           20190105          20190105       20190105           20190105
# 1           20190110          20190110       20190110           20190110
# 2           20190120          20190120       20190120           20190120
# 3           20190125          20190125       20190125           20190125
# 4           20190130          20190130       20190130           20190130
# ..               ...               ...            ...                ...
# 66          20191211          20191211       20191211           20191211
# 67          20191216          20191216       20191216           20191216
# 68          20191221          20191221       20191221           20191221
# 69          20191226          20191226       20191226           20191226
# 70          20191231          20191231       20191231           20191231
#
# [71 rows x 8 columns]

# %%
dates_df.all(axis = 0)
# Out:
# ./dataset_v0/R        True
# ./dataset_v0/G        True
# ./dataset_v0/B        True
# ./dataset_v0/NIR      True
# ./dataset_v0/NDVI     True
# ./dataset_v0/SWIR     True
# ./dataset_v0/W        True
# ./dataset_v0/THETA    True
# dtype: bool

# %% [markdown]
# We can be sure all bands contains the same dates
